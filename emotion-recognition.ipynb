# %%
#!pip install opencv-python

# %%
import cv2

# %%
img = cv2.imread('angry.jpeg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
#!pip install deepface

# %%
#!pip install tf-keras

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img, actions=("emotion"))

# %%
#type(predictions)

# %%
# predictions

# %%
emotion = predictions[0]['dominant_emotion']

# %%
face_cascade = cv2.CascadeClassifier('haar_face.xml')

# %%
grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayimg)

# %%
faces = face_cascade.detectMultiScale(grayimg, 1.1, 3)

# %%
faces
# Out:
# array([[108, 115, 326, 326]], dtype=int32)

# %%
for a,b,c,d in faces:
    cv2.rectangle(img, (a,b), (a+c,b+d), (255,0,0), 3)

# %%
font_scale = 1.0  # Adjust the font scale as needed
text_size = cv2.getTextSize(emotion, cv2.FONT_HERSHEY_SIMPLEX, font_scale, 2)[0]
text_position = (a + c // 2 - text_size[0] // 2, b + d + 20)  # Adjust 20 to position the text as you like

# Add black background
cv2.rectangle(img, (text_position[0], text_position[1] - text_size[1]), 
              (text_position[0] + text_size[0], text_position[1]), (0, 0, 0), -1)

# Put text centered below the bounding box
cv2.putText(img, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), 2)


plt.imshow(img)
